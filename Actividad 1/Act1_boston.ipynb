# %% [markdown]
# # Boston
# Ivanna Maldonado Cervantes

# %% [markdown]
# 1. Instalación de librerías necesarias.

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl

# %% [markdown]
# 2. Importar librerías que vamos a usar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 3. Se converite de dataset a dataframe.

# %%
df= pd.read_csv("listingsBoston.csv")
df
# Out:
#                        id                                       listing_url  \
# 0                    3781                 https://www.airbnb.com/rooms/3781
# 1                    5506                 https://www.airbnb.com/rooms/5506
# 2                    6695                 https://www.airbnb.com/rooms/6695
# 3                    8789                 https://www.airbnb.com/rooms/8789
# 4                   10811                https://www.airbnb.com/rooms/10811
# ...                   ...                                               ...
# 4555  1442936143734248350  https://www.airbnb.com/rooms/1442936143734248350
# 4556  1442940477243281647  https://www.airbnb.com/rooms/1442940477243281647
# 4557  1445146141923468353  https://www.airbnb.com/rooms/1445146141923468353
# 4558  1445761247286385772  https://www.airbnb.com/rooms/1445761247286385772
# 4559  1445867715555794708  https://www.airbnb.com/rooms/1445867715555794708
#
#            scrape_id last_scraped       source  \
# ...

# %% [markdown]
# 4. Obtenemos la información del DF

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4560 entries, 0 to 4559
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4560 non-null   int64
#  1   listing_url                                   4560 non-null   object
#  2   scrape_id                                     4560 non-null   int64
#  3   last_scraped                                  4560 non-null   object
#  4   source                                        4560 non-null   object
#  5   name                                          4560 non-null   object
#  6   description                                   4515 non-null   object
#  7   neighborhood_overview                         2324 non-null   object
#  8   picture_url                                   4560 non-null   object
# ...

# %% [markdown]
# 5. Accedemos a un array 1D, específicamente a la fila de las variables con las que se van a trabajar.

# %%
fila0 = df.iloc[0]
fila0
# Out:
# id                                                                           3781
# listing_url                                     https://www.airbnb.com/rooms/3781
# scrape_id                                                          20250619031426
# last_scraped                                                           2025-06-19
# source                                                                city scrape
#                                                               ...
# calculated_host_listings_count                                                  1
# calculated_host_listings_count_entire_homes                                     1
# calculated_host_listings_count_private_rooms                                    0
# calculated_host_listings_count_shared_rooms                                     0
# reviews_per_month                                                            0.21
# Name: 0, Length: 79, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %% [markdown]
# 7. Se eligen las 50 variables con las que se van a trabajar.

# %%
dfboston = df.iloc[:, [
0, 30, 31, 28, 70, 13, 32, 33, 34, 35, 36, 37, 38, 39, 73, 72, 41, 42,
18, 12, 15, 16, 17, 26, 22, 14, 24, 40, 51, 52, 53, 54, 47, 48, 50, 49,
56, 57, 58, 65, 66, 67, 68, 69, 71, 78, 63, 64, 61, 62
]]
dfboston
# Out:
#                        id   latitude  longitude neighbourhood_cleansed  \
# 0                    3781  42.364130 -71.029910            East Boston
# 1                    5506  42.328440 -71.095810                Roxbury
# 2                    6695  42.328020 -71.093870                Roxbury
# 3                    8789  42.358670 -71.063070            Beacon Hill
# 4                   10811  42.351730 -71.086850               Back Bay
# ...                   ...        ...        ...                    ...
# 4555  1442936143734248350  42.349840 -71.071990               Back Bay
# 4556  1442940477243281647  42.347708 -71.073669               Back Bay
# 4557  1445146141923468353  42.320754 -71.110194          Jamaica Plain
# 4558  1445761247286385772  42.376300 -71.030647            East Boston
# 4559  1445867715555794708  42.286404 -71.120927             Roslindale
#
#       review_scores_location                 host_location  \
# ...

# %% [markdown]
# 8. Se corrobora que se hayan elegido 50 variables

# %%
num_columnas = dfboston.shape[1]
num_columnas
# Out:
# 50

# %% [markdown]
# 9. Se convierte el array a un archivo csv.

# %%
dfboston.to_csv("Boston50.csv")
