# %% [markdown]
# Ivanna Maldonado Cervantes

# %%
#Importamos las librerias necesarias
import pandas as pd
import numpy as np
import os
import Act8_Ivanna as act

# %%
#Se realiza el llamado a la función "cargar_dataset" para leer el archivo
df_csv=act.cargar_dataset('listingsBoston.csv')

# %% [markdown]
# ***Función de Limpieza de Valores Nulos***

# %%
pd.set_option("display.max_rows", None) # muestra todas las filas  #formato

# %%
# Visualizamos todos los valores nulos del datafranme orginal
df_csv.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
# name                                               0
# description                                       45
# neighborhood_overview                           2236
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                    923
# host_about                                      1511
# host_response_time                               531
# host_response_rate                               531
# host_acceptance_rate                             486
# ...

# %%
# Llamamos a las funciones una por una del archivo py 
df_ffill = act.ffill_df(df_csv)
df_ffill.head(3)
# Out:
# /Users/hijos/Desktop/Analitica Prof/Prof. Alfredo/08_examen/Act8_Ivanna.py:29: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return df.fillna(method="ffill")
#      id                        listing_url       scrape_id last_scraped  \
# 0  3781  https://www.airbnb.com/rooms/3781  20250619031426   2025-06-19
# 1  5506  https://www.airbnb.com/rooms/5506  20250619031426   2025-06-19
# 2  6695  https://www.airbnb.com/rooms/6695  20250619031426   2025-06-19
#
#         source                                            name  \
# 0  city scrape                       HARBORSIDE-Walk to subway
# 1  city scrape  ** Fort Hill Inn Private! Minutes to center!**
# 2  city scrape   Fort Hill Inn *Sunny* 1 bedroom, condo duplex
#
#                                          description  \
# 0  Fully separate apartment in a two apartment bu...
# 1  **THE BEST Value in BOSTON!!*** PRIVATE GUEST ...
# ...

# %%
# Comprobamos que se haya realizado lo indicado en la función.
df_ffill.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
# name                                               0
# description                                        0
# neighborhood_overview                              0
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                      0
# host_about                                         0
# host_response_time                                 0
# host_response_rate                                 0
# host_acceptance_rate                               0
# ...

# %%
df_bfill= act.bfill_df(df_csv)
df_bfill.head(3)
# Out:
# /Users/hijos/Desktop/Analitica Prof/Prof. Alfredo/08_examen/Act8_Ivanna.py:34: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return df.fillna(method="bfill")
#      id                        listing_url       scrape_id last_scraped  \
# 0  3781  https://www.airbnb.com/rooms/3781  20250619031426   2025-06-19
# 1  5506  https://www.airbnb.com/rooms/5506  20250619031426   2025-06-19
# 2  6695  https://www.airbnb.com/rooms/6695  20250619031426   2025-06-19
#
#         source                                            name  \
# 0  city scrape                       HARBORSIDE-Walk to subway
# 1  city scrape  ** Fort Hill Inn Private! Minutes to center!**
# 2  city scrape   Fort Hill Inn *Sunny* 1 bedroom, condo duplex
#
#                                          description  \
# 0  Fully separate apartment in a two apartment bu...
# 1  **THE BEST Value in BOSTON!!*** PRIVATE GUEST ...
# ...

# %%
df_bfill.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
# name                                               0
# description                                        0
# neighborhood_overview                              3
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                      0
# host_about                                         0
# host_response_time                                 0
# host_response_rate                                 0
# host_acceptance_rate                               0
# ...

# %%
df_str= act.fillna_string(df_csv)
df_str.tail()
# Out:
#                        id                                       listing_url  \
# 4555  1442936143734248350  https://www.airbnb.com/rooms/1442936143734248350
# 4556  1442940477243281647  https://www.airbnb.com/rooms/1442940477243281647
# 4557  1445146141923468353  https://www.airbnb.com/rooms/1445146141923468353
# 4558  1445761247286385772  https://www.airbnb.com/rooms/1445761247286385772
# 4559  1445867715555794708  https://www.airbnb.com/rooms/1445867715555794708
#
#            scrape_id last_scraped       source  \
# 4555  20250619031426   2025-06-19  city scrape
# 4556  20250619031426   2025-06-19  city scrape
# 4557  20250619031426   2025-06-19  city scrape
# 4558  20250619031426   2025-06-19  city scrape
# 4559  20250619031426   2025-06-19  city scrape
#
#                                                    name  \
# 4555             2 level, 2 bed with office in Back Bay
# 4556        Sunny 2BR w/ Office, Near Copley & Shopping
# ...

# %%
df_str.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
# name                                               0
# description                                        0
# neighborhood_overview                              0
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                      0
# host_about                                         0
# host_response_time                                 0
# host_response_rate                                 0
# host_acceptance_rate                               0
# ...

# %%
df_mean= act.fillna_mean(df_csv)
df_mean.head(3)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3781  https://www.airbnb.com/rooms/3781  20250619031426   2025-06-19
# 1  5506  https://www.airbnb.com/rooms/5506  20250619031426   2025-06-19
# 2  6695  https://www.airbnb.com/rooms/6695  20250619031426   2025-06-19
#
#         source                                            name  \
# 0  city scrape                       HARBORSIDE-Walk to subway
# 1  city scrape  ** Fort Hill Inn Private! Minutes to center!**
# 2  city scrape   Fort Hill Inn *Sunny* 1 bedroom, condo duplex
#
#                                          description  \
# 0  Fully separate apartment in a two apartment bu...
# 1  **THE BEST Value in BOSTON!!*** PRIVATE GUEST ...
# 2  Comfortable,  Fully Equipped private apartment...
#
#                                neighborhood_overview  \
# 0  Mostly quiet ( no loud music, no crowed sidewa...
# 1  Peaceful, Architecturally interesting, histori...
# ...

# %%
df_mean.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
# name                                               0
# description                                       45
# neighborhood_overview                           2236
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                    923
# host_about                                      1511
# host_response_time                               531
# host_response_rate                               531
# host_acceptance_rate                             486
# ...

# %%
df_median= act.fillna_median(df_csv)
df_median.head()
# Out:
# /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /opt/anaconda3/envs/Analitica/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
#       id                         listing_url       scrape_id last_scraped  \
# 0   3781   https://www.airbnb.com/rooms/3781  20250619031426   2025-06-19
# 1   5506   https://www.airbnb.com/rooms/5506  20250619031426   2025-06-19
# 2   6695   https://www.airbnb.com/rooms/6695  20250619031426   2025-06-19
# 3   8789   https://www.airbnb.com/rooms/8789  20250619031426   2025-06-19
# 4  10811  https://www.airbnb.com/rooms/10811  20250619031426   2025-06-19
#
#         source                                               name  \
# 0  city scrape                          HARBORSIDE-Walk to subway
# ...

# %%
df_median.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
# name                                               0
# description                                       45
# neighborhood_overview                           2236
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                    923
# host_about                                      1511
# host_response_time                               531
# host_response_rate                               531
# host_acceptance_rate                             486
# ...

# %%
df_const = act.fillna_constant(df_csv)
df_const.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   3781   https://www.airbnb.com/rooms/3781  20250619031426   2025-06-19
# 1   5506   https://www.airbnb.com/rooms/5506  20250619031426   2025-06-19
# 2   6695   https://www.airbnb.com/rooms/6695  20250619031426   2025-06-19
# 3   8789   https://www.airbnb.com/rooms/8789  20250619031426   2025-06-19
# 4  10811  https://www.airbnb.com/rooms/10811  20250619031426   2025-06-19
#
#         source                                               name  \
# 0  city scrape                          HARBORSIDE-Walk to subway
# 1  city scrape     ** Fort Hill Inn Private! Minutes to center!**
# 2  city scrape      Fort Hill Inn *Sunny* 1 bedroom, condo duplex
# 3  city scrape                Curved Glass Studio/1bd facing Park
# 4  city scrape  Bostons Best Rentals -Studio Prestigious Back Bay
#
#                                          description  \
# 0  Fully separate apartment in a two apartment bu...
# ...

# %%
df_const.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
# name                                               0
# description                                       45
# neighborhood_overview                           2236
# picture_url                                        0
# host_id                                            0
# host_url                                           0
# host_name                                          0
# host_since                                         0
# host_location                                    923
# host_about                                      1511
# host_response_time                               531
# host_response_rate                               531
# host_acceptance_rate                             486
# ...

# %%
# Ya que es un resumen, se visualizan directamente el resumen de los valores nulos
df_resu = act.resumen_nulos(df_csv)
df_resu
# Out:
# (                                              Nulos  Porcentaje (%)
#  id                                                0            0.00
#  listing_url                                       0            0.00
#  scrape_id                                         0            0.00
#  last_scraped                                      0            0.00
#  source                                            0            0.00
#  name                                              0            0.00
#  description                                      45            0.99
#  neighborhood_overview                          2236           49.04
#  picture_url                                       0            0.00
#  host_id                                           0            0.00
#  host_url                                          0            0.00
#  host_name                                         0            0.00
#  host_since                                        0            0.00
# ...
