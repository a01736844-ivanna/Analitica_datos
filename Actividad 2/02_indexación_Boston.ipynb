# %% [markdown]
# ## Actividad 2: Indexación
# Ivanna Maldonado Cervantes (Boston)

# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("listingsBoston.csv")
df
# Out:
#                        id                                       listing_url  \
# 0                    3781                 https://www.airbnb.com/rooms/3781
# 1                    5506                 https://www.airbnb.com/rooms/5506
# 2                    6695                 https://www.airbnb.com/rooms/6695
# 3                    8789                 https://www.airbnb.com/rooms/8789
# 4                   10811                https://www.airbnb.com/rooms/10811
# ...                   ...                                               ...
# 4555  1442936143734248350  https://www.airbnb.com/rooms/1442936143734248350
# 4556  1442940477243281647  https://www.airbnb.com/rooms/1442940477243281647
# 4557  1445146141923468353  https://www.airbnb.com/rooms/1445146141923468353
# 4558  1445761247286385772  https://www.airbnb.com/rooms/1445761247286385772
# 4559  1445867715555794708  https://www.airbnb.com/rooms/1445867715555794708
#
#            scrape_id last_scraped       source  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4560 entries, 0 to 4559
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4560 non-null   int64
#  1   listing_url                                   4560 non-null   object
#  2   scrape_id                                     4560 non-null   int64
#  3   last_scraped                                  4560 non-null   object
#  4   source                                        4560 non-null   object
#  5   name                                          4560 non-null   object
#  6   description                                   4515 non-null   object
#  7   neighborhood_overview                         2324 non-null   object
#  8   picture_url                                   4560 non-null   object
# ...

# %%
#Array 2D con columnas
dfcolumnas = df[['host_name', 'host_since', 'host_since', 'neighbourhood', 'property_type', 'room_type', 'price']] #pueden ser consecutivas o no consecutivas
dfcolumnas
# Out:
#      host_name  host_since  host_since            neighbourhood  \
# 0        Frank  2008-12-03  2008-12-03  Neighborhood highlights
# 1        Terry  2009-02-19  2009-02-19  Neighborhood highlights
# 2        Terry  2009-02-19  2009-02-19  Neighborhood highlights
# 3         Anne  2009-07-22  2009-07-22  Neighborhood highlights
# 4     Michelle  2009-09-16  2009-09-16  Neighborhood highlights
# ...        ...         ...         ...                      ...
# 4555      Nina  2019-03-21  2019-03-21  Neighborhood highlights
# 4556      Nina  2019-03-21  2019-03-21  Neighborhood highlights
# 4557   Allison  2013-03-15  2013-03-15                      NaN
# 4558    Olsian  2025-06-03  2025-06-03                      NaN
# 4559    Plushy  2018-03-29  2018-03-29                      NaN
#
#                     property_type        room_type    price
# 0              Entire rental unit  Entire home/apt  $125.00
# 1              Entire guest suite  Entire home/apt  $142.00
# ...

# %%
#Array 2D con filas, con todas las columnas
df_filas= df.iloc[[1, 50, 499, 500, 605, 1500] + list(range(100, 200)), :]
df_filas
# Out:
#            id                            listing_url       scrape_id  \
# 1        5506      https://www.airbnb.com/rooms/5506  20250619031426
# 50     962610    https://www.airbnb.com/rooms/962610  20250619031426
# 499  15020558  https://www.airbnb.com/rooms/15020558  20250619031426
# 500  15085512  https://www.airbnb.com/rooms/15085512  20250619031426
# 605  18396209  https://www.airbnb.com/rooms/18396209  20250619031426
# ..        ...                                    ...             ...
# 195   5884429   https://www.airbnb.com/rooms/5884429  20250619031426
# 196   5919529   https://www.airbnb.com/rooms/5919529  20250619031426
# 197   5927267   https://www.airbnb.com/rooms/5927267  20250619031426
# 198   5932402   https://www.airbnb.com/rooms/5932402  20250619031426
# 199   5967421   https://www.airbnb.com/rooms/5967421  20250619031426
#
#     last_scraped           source  \
# 1     2025-06-19      city scrape
# 50    2025-06-19      city scrape
# ...

# %%
# Segundo array de filas, con columnas específicas
df_filas2= df.iloc[[125, 252, 700, 1000] + list(range(300, 550)) + list(range(1250, 4559)), :]
df_filas2
df1=df_filas2[['host_id', 'host_location', 'host_acceptance_rate', 'bathrooms', 'amenities', 'review_scores_value']]
df1
# Out:
#         host_id                 host_location host_acceptance_rate  bathrooms  \
# 125     5408229                    Boston, MA                  58%        1.0
# 252    22348222  Massachusetts, United States                 100%        1.0
# 700    46580723                           NaN                 100%        1.0
# 1000      85130                    Boston, MA                 100%        1.0
# 300    30489899                    Boston, MA                 100%        1.5
# ...         ...                           ...                  ...        ...
# 4554  700783118                           NaN                  NaN        1.0
# 4555  250399091                           NaN                 100%        2.0
# 4556  250399091                           NaN                 100%        1.0
# 4557    5480536                    Boston, MA                  96%        1.0
# 4558  699041704                           NaN                 100%        1.0
#
# ...

# %%
# Array de 50 columnas
dfboston = df.iloc[:, [
0, 30, 31, 28, 70, 13, 32, 33, 34, 35, 36, 37, 38, 39, 73, 72, 41, 42,
18, 12, 15, 16, 17, 26, 22, 14, 24, 40, 51, 52, 53, 54, 47, 48, 50, 49,
56, 57, 58, 65, 66, 67, 68, 69, 71, 78, 63, 64, 61, 62
]]
dfboston
# Out:
#                        id   latitude  longitude neighbourhood_cleansed  \
# 0                    3781  42.364130 -71.029910            East Boston
# 1                    5506  42.328440 -71.095810                Roxbury
# 2                    6695  42.328020 -71.093870                Roxbury
# 3                    8789  42.358670 -71.063070            Beacon Hill
# 4                   10811  42.351730 -71.086850               Back Bay
# ...                   ...        ...        ...                    ...
# 4555  1442936143734248350  42.349840 -71.071990               Back Bay
# 4556  1442940477243281647  42.347708 -71.073669               Back Bay
# 4557  1445146141923468353  42.320754 -71.110194          Jamaica Plain
# 4558  1445761247286385772  42.376300 -71.030647            East Boston
# 4559  1445867715555794708  42.286404 -71.120927             Roslindale
#
#       review_scores_location                 host_location  \
# ...

# %%
#Convertir arrays a CSV
#punto a)
dfcolumnas.to_csv("arrayColumnas.csv")

#punto b)
df_filas.to_csv("arrayFilas.csv")

#punto c)
df_filas2.to_csv("arrayFilas2.csv")

#punto d)
dfboston.to_csv("boston50.csv")
